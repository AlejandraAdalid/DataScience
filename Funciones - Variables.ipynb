# %% [markdown]
# #**Python para DS - Introducción al Lenguaje**

# %%
1 + 1
# Out:
# 2

# %%
'Alejandra'
# Out:
# 'Alejandra'

# %%
nombre = 'Alejandra'

# %%
nombre
# Out:
# 'Alejandra'

# %%
edad = 31

# %%
edad
# Out:
# 31

# %% [markdown]
# #Mi primera función

# %%
print('El nombre es Alejandra y su edad es 31 años')
# Out:
# El nombre es Alejandra y su edad es 31 años

# %%
print(f'El nombre es {nombre} y su edad es {edad} años')
# Out:
# El nombre es Alejandra y su edad es 31 años

# %%
def saludar():
  nombre = input('Digite su nombre: ')
  print(f'Hola {nombre} sea bienvenid@!!!')

# %%
saludar()
# Out:
# Digite su nombre: Alejandra
# Hola Alejandra sea bienvenid@!!!

# %%
saludar()
# Out:
# Digite su nombre: Elsa
# Hola Elsa sea bienvenid@!!!
